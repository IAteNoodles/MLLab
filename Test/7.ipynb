# %%
import numpy as np, matplotlib.pyplot as plt, seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.datasets import fetch_california_housing

# -------- Linear Regression --------
data = fetch_california_housing()
X, y = data.data[:, [5]], data.target

lr = LinearRegression().fit(X, y)
plt.scatter(X, y)
plt.plot(X, lr.predict(X))
plt.title("Linear Regression")
plt.show()

# -------- Polynomial Regression --------
mpg = sns.load_dataset('mpg').dropna()
X, y = mpg[['horsepower']], mpg['mpg']

poly = PolynomialFeatures(2)
model = LinearRegression().fit(poly.fit_transform(X), y)

x_range = np.linspace(X.min(), X.max(), 100)
plt.scatter(X, y)
plt.plot(x_range, model.predict(poly.transform(x_range)))
plt.title("Polynomial Regression")
plt.show()
# Out:
# c:\Users\Noodl\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()

# %%
X,y = data.data[:,[5]], data.target

# %%
model = LinearRegression().fit(X,y)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,y)
plt.plot(X, model.predict(X), c='green')
plt.show()

# %%
mpg = sns.load_dataset('mpg').dropna()

# %%
X,Y = mpg[['horsepower']], mpg['mpg']

# %%
poly = PolynomialFeatures(2)

# %%
model = LinearRegression().fit(poly.fit_transform(X),Y)

# %%
X_range = np.linspace(X.min(), X.max(), 100)

# %%
plt.scatter(X,Y)
plt.plot(X_range, model.predict(poly.transform(X_range)), c='green')
plt.show()
# Out:
# c:\Users\Noodl\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
