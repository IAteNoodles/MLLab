# %%
import csv
hypo =  ['%' , '%' , '%' , '%' , '%' , '%' ]

with open(r'F:\COLLEGE\NOTES\6TH SEM\ML Lab\Datasets\Training_Data.csv') as csv_file:
    read_csv = csv.reader(csv_file,delimiter=',')
    print(read_csv)
    data = []
    print("\n The given training examples are: ")
    for row in read_csv:
        print(row)
        if row[len(row)-1].lower() == "yes":
            data.append(row)

print("\n The positive training examples are: ")
for x in data:
    print(x)

print("\n")
Total_Examples = len(data)
print(Total_Examples)

i = 0
j = 0
k = 0
print("The steps of Find-S algorithm are \n",hypo)
list=[]
p = 0
d = len(data[p]) - 1

for j in range(d):
    list.append(data[i][j])
hypo = list

i = 1
for i in range(Total_Examples):
    for k in range(d):
        if hypo[k] != data[i][k]:
            hypo[k] = '?'
            k += 1
        else:
            hypo[k]
    print(hypo)
i += 1
print("\n The maximally Specific Find-S hypothesis for the given training data is : ")
list = []
for i in range(d):
    list.append(hypo[i])
print(list)
csv_file.close()
# Out:
# ...
#
#  The given training examples are:
# ['sky', 'airtemp', 'humidity', 'wind', 'water', 'forecast', 'enjoysport']
# ['sunny', 'warm', 'normal', 'strong', 'warm', 'same', 'yes']
# ['sunny', 'warm', 'high', 'strong', 'warm', 'same', 'yes']
# ['rainy', 'cold', 'high', 'strong', 'warm', 'change', 'no']
# ['sunny', 'warm', 'high', 'strong', 'cool', 'change', 'yes']
#
#  The positive training examples are:
# ['sunny', 'warm', 'normal', 'strong', 'warm', 'same', 'yes']
# ['sunny', 'warm', 'high', 'strong', 'warm', 'same', 'yes']
# ['sunny', 'warm', 'high', 'strong', 'cool', 'change', 'yes']
#
#
# 3
# The steps of Find-S algorithm are
#  ['%', '%', '%', '%', '%', '%']
# ['sunny', 'warm', 'normal', 'strong', 'warm', 'same']
# ['sunny', 'warm', '?', 'strong', 'warm', 'same']
# ['sunny', 'warm', '?', 'strong', '?', '?']
#
#  The maximally Specific Find-S hypothesis for the given training data is :
# ['sunny', 'warm', '?', 'strong', '?', '?']
